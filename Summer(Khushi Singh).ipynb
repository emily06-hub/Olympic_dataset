# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('summer_olympics.csv')

# %%
data
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data.describe()
# Out:
#                Year
# count  31165.000000
# mean    1970.482785
# std       33.158416
# min     1896.000000
# 25%     1948.000000
# 50%     1980.000000
# 75%     2000.000000
# max     2012.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Removal Of Unneccessary Data Column

# %%
data.drop('Discipline',axis = 1, inplace = True)

# %%
data
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# ...

# %% [markdown]
# ## Removal of Null Value Row

# %%
data.isnull().sum()
# Out:
# Year       0
# City       0
# Sport      0
# Athlete    0
# Country    4
# Gender     0
# Event      0
# Medal      0
# dtype: int64

# %% [markdown]
# ### As the values that are null are very few so we will not remove them.

# %% [markdown]
# # Questions Of Assignment

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
count = 0
for cities in df['City'].unique():
    print(cities)
    count += 1
print("\nIt had been played in " , count, " different cities.")
# Out:
# Athens
# Paris
# St Louis
# London
# Stockholm
# Antwerp
# Amsterdam
# Los Angeles
# Berlin
# Helsinki
# Melbourne / Stockholm
# Rome
# Tokyo
# Mexico
# Munich
# Montreal
# Moscow
# Seoul
# Barcelona
# Atlanta
# Sydney
# Beijing
#
# It had been played in  22  different cities.

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# ...

# %%
sol = df.groupby(['Medal']).get_group('Gold')

# %%
sol
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 6      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 9      1896  Athens   Aquatics              NEUMANN, Paul     AUT    Men
# 13     1896  Athens  Athletics              BURKE, Thomas     USA    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31145  2012  London  Wrestling         NOROOZI, Omid Haji     IRI    Men
# 31149  2012  London  Wrestling              KIM, Hyeonwoo     KOR    Men
# 31153  2012  London  Wrestling              VLASOV, Roman     RUS    Men
# 31157  2012  London  Wrestling              KHUGAEV, Alan     RUS    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
#
#                             Event Medal
# 0                  100M Freestyle  Gold
# ...

# %%
data = []

for Sport in sol['Sport'].unique():
  data.append([Sport , len(sol[sol['Sport'] == Sport])])

pd.DataFrame(data, columns = ['Sport','freq']).sort_values(by = 'freq', ascending = False).head()
# Out:
#          Sport  freq
# 0     Aquatics  1421
# 1    Athletics  1215
# 17      Rowing   890
# 4   Gymnastics   820
# 3      Fencing   552

# %%
pd.DataFrame(data, columns = ['Sport','freq']).sort_values(by = 'freq', ascending = False).head().plot(x = 'Sport', y = 'freq', kind = 'bar')

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
df
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# ...

# %%
data = []

for Sport in df['Sport'].unique():
  data.append([Sport , len(df[df['Sport'] == Sport])])

pd.DataFrame(data, columns = ['Sport','freq']).sort_values(by = 'freq', ascending = False).head()
# Out:
#          Sport  freq
# 0     Aquatics  4170
# 1    Athletics  3638
# 17      Rowing  2667
# 4   Gymnastics  2307
# 3      Fencing  1613

# %%
pd.DataFrame(data, columns = ['Sport','freq']).sort_values(by = 'freq', ascending = False).head().plot(x = 'Sport', y = 'freq', kind = 'bar', color = 'red')

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# ...

# %%
data = []

for Athlete in df['Athlete'].unique():
  data.append([Athlete , len(df[df['Athlete'] == Athlete])])

pd.DataFrame(data, columns = ['Athlete','freq']).sort_values(by = 'freq', ascending = False).head()
# Out:
#                     Athlete  freq
# 18640       PHELPS, Michael    22
# 7197       LATYNINA, Larisa    18
# 9948     ANDRIANOV, Nikolay    15
# 6591           ONO, Takashi    13
# 5103   MANGIAROTTI, Edoardo    13

# %%
pd.DataFrame(data, columns = ['Athlete','freq']).sort_values(by = 'freq', ascending = False).head().plot(x = 'Athlete', y = 'freq', kind = 'bar', color = 'black')

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# ...

# %%
sol
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 6      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 9      1896  Athens   Aquatics              NEUMANN, Paul     AUT    Men
# 13     1896  Athens  Athletics              BURKE, Thomas     USA    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31145  2012  London  Wrestling         NOROOZI, Omid Haji     IRI    Men
# 31149  2012  London  Wrestling              KIM, Hyeonwoo     KOR    Men
# 31153  2012  London  Wrestling              VLASOV, Roman     RUS    Men
# 31157  2012  London  Wrestling              KHUGAEV, Alan     RUS    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
#
#                             Event Medal
# 0                  100M Freestyle  Gold
# ...

# %%
data = []

for Athlete in sol['Athlete'].unique():
  data.append([Athlete , len(sol[sol['Athlete'] == Athlete])])

pd.DataFrame(data, columns = ['Athlete','freq']).sort_values(by = 'freq', ascending = False).head()
# Out:
#                Athlete  freq
# 6851   PHELPS, Michael    18
# 3320       SPITZ, Mark     9
# 2714  LATYNINA, Larisa     9
# 4630       LEWIS, Carl     9
# 907       NURMI, Paavo     9

# %%
pd.DataFrame(data, columns = ['Athlete','freq']).sort_values(by = 'freq', ascending = False).head().plot(x = 'Athlete', y = 'freq', kind = 'bar', color = 'pink', figsize = (8,6))

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
solution6 = df.loc[df['Country'] == 'IND']
solution6
# Out:
#        Year       City      Sport               Athlete Country Gender  \
# 241    1900      Paris  Athletics     PRITCHARD, Norman     IND    Men
# 244    1900      Paris  Athletics     PRITCHARD, Norman     IND    Men
# 5512   1928  Amsterdam     Hockey  ALLEN, Richard James     IND    Men
# 5513   1928  Amsterdam     Hockey           CHAND, Dyan     IND    Men
# 5514   1928  Amsterdam     Hockey   GATELEY, Maurice A.     IND    Men
# ...     ...        ...        ...                   ...     ...    ...
# 29879  2012     London     Boxing             KOM, Mary     IND  Women
# 30841  2012     London   Shooting         NARANG, Gagan     IND    Men
# 30849  2012     London   Shooting          KUMAR, Vijay     IND    Men
# 31111  2012     London  Wrestling       DUTT, Yogeshwar     IND    Men
# 31118  2012     London  Wrestling         KUMAR, Sushil     IND    Men
#
#                   Event   Medal
# 241                200M  Silver
# 244        200M Hurdles  Silver
# ...

# %%
Final_solution6 = solution6.loc[df['Medal'] == 'Gold']
Final_solution6.sort_values(by = 'Year', ascending = True).head(1)
# Out:
#       Year       City   Sport               Athlete Country Gender   Event  \
# 5512  1928  Amsterdam  Hockey  ALLEN, Richard James     IND    Men  Hockey
#
#      Medal
# 5512  Gold

# %% [markdown]
# #### Hence we got the first year in which India Won its first gold medal : 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
df
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# ...

# %%
data = []

for Event in df['Event'].unique():
  data.append([Event , len(df[df['Event'] == Event])])

pd.DataFrame(data, columns = ['Event','freq']).sort_values(by = 'freq', ascending = False).head()
# Out:
#                 Event  freq
# 80           Football  1497
# 176            Hockey  1422
# 138  Team Competition  1147
# 327        Basketball  1012
# 337          Handball   973

# %%
pd.DataFrame(data, columns = ['Event','freq']).sort_values(by = 'freq', ascending = False).head().plot(x = 'Event', y = 'freq', kind = 'bar', color = 'blue')

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df
# Out:
#        Year    City      Sport                    Athlete Country Gender  \
# 0      1896  Athens   Aquatics              HAJOS, Alfred     HUN    Men
# 1      1896  Athens   Aquatics           HERSCHMANN, Otto     AUT    Men
# 2      1896  Athens   Aquatics          DRIVAS, Dimitrios     GRE    Men
# 3      1896  Athens   Aquatics         MALOKINIS, Ioannis     GRE    Men
# 4      1896  Athens   Aquatics         CHASAPIS, Spiridon     GRE    Men
# ...     ...     ...        ...                        ...     ...    ...
# 31160  2012  London  Wrestling         JANIKOWSKI, Damian     POL    Men
# 31161  2012  London  Wrestling  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  2012  London  Wrestling             TOTROV, Rustam     RUS    Men
# 31163  2012  London  Wrestling          ALEKSANYAN, Artur     ARM    Men
# 31164  2012  London  Wrestling             LIDBERG, Jimmy     SWE    Men
#
#                             Event   Medal
# 0                  100M Freestyle    Gold
# ...

# %%
women = df.groupby(['Gender']).get_group('Women')

# %%
women
# Out:
#        Year    City      Sport                   Athlete Country Gender  \
# 416    1900   Paris       Golf              PRATT, Daria     USA  Women
# 417    1900   Paris       Golf     ABBOTT, Margaret Ives     USA  Women
# 418    1900   Paris       Golf         WHITTIER, Pauline     USA  Women
# 639    1900   Paris     Tennis             JONES, Marion     ZZX  Women
# 640    1900   Paris     Tennis         ROSENBAUM, Hedwig     ZZX  Women
# ...     ...     ...        ...                       ...     ...    ...
# 31116  2012  London  Wrestling           VOLOSOVA, Lubov     RUS  Women
# 31121  2012  London  Wrestling        VOROBIEVA, Natalia     RUS  Women
# 31122  2012  London  Wrestling  HRISTOVA, Stanka Zlateva     BUL  Women
# 31123  2012  London  Wrestling          MANYUROVA, Guzel     KAZ  Women
# 31124  2012  London  Wrestling              UNDA, Maider     ESP  Women
#
#                Event   Medal
# 416       Individual  Bronze
# 417       Individual    Gold
# ...

# %%
gold = women.groupby(['Medal']).get_group('Gold')

# %%
gold
# Out:
#        Year      City          Sport                Athlete Country Gender  \
# 417    1900     Paris           Golf  ABBOTT, Margaret Ives     USA  Women
# 641    1900     Paris         Tennis      COOPER, Charlotte     GBR  Women
# 649    1900     Paris         Tennis      COOPER, Charlotte     GBR  Women
# 710    1904  St Louis        Archery  HOWELL, Matilda Scott     USA  Women
# 713    1904  St Louis        Archery  HOWELL, Matilda Scott     USA  Women
# ...     ...       ...            ...                    ...     ...    ...
# 31081  2012    London  Weightlifting  VALENTIN PEREZ, Lidia     ESP  Women
# 31097  2012    London      Wrestling          OBARA, Hitomi     JPN  Women
# 31105  2012    London      Wrestling         YOSHIDA, Saori     JPN  Women
# 31113  2012    London      Wrestling            ICHO, Kaori     JPN  Women
# 31121  2012    London      Wrestling     VOROBIEVA, Natalia     RUS  Women
#
#                                          Event Medal
# ...

# %%
data = []

for Sport in gold['Sport'].unique():
  data.append([Sport, len(gold[gold['Sport'] == Sport])])

pd.DataFrame(data, columns = ['Sport','freq']).sort_values(by = 'freq', ascending = False).head()
# Out:
#          Sport  freq
# 4     Aquatics   589
# 7    Athletics   389
# 8   Gymnastics   268
# 14      Rowing   217
# 11  Volleyball   166

# %%
pd.DataFrame(data, columns = ['Sport','freq']).sort_values(by = 'freq', ascending = False).head().plot(x = 'Sport', y = 'freq', kind = 'bar', color = 'orange')
